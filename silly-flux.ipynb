# %% [markdown]
# # Start Flux

# %%
# @markdown # Start 💕
# @markdown Click to download Model and Libraries

from IPython.display import display, HTML, clear_output
import ipywidgets as widgets

clear_output()

# %cd /content
# !git clone -b totoro4 https://github.com/camenduru/ComfyUI /content/TotoroUI
# %cd /content/TotoroUI

# !pip install -q torchsde einops diffusers accelerate xformers==0.0.28.post2 gradio==3.50.2 python-multipart==0.0.12
# !apt -y install -qq aria2

clear_output()

button = widgets.Button(description="Done! <3", button_style="success")
display(button)
# Out:
# Button(button_style='success', description='Done! <3', style=ButtonStyle())

# %% [markdown]
# ---

# %%
# @markdown # LoRA and Flux Models ✨
# @markdown Enter the name of the Hugging Face repository from which the model is loaded.

model_repo = "Leo71288/cute_cat_LoRA"  # @param {type:"string"}
# @markdown Enter the name of the LoRA on the Hugging Face from which the model is loaded
lora_model = "cm49oscux166diz18hkynb3ld"     # @param {type:"string"}

# @markdown Enter the Hugging Face token to access private models. (not work sowwy)
hf_token = ""  # @param {type:"string"}

import os
import random
import torch
import numpy as np
from PIL import Image
import nodes
from nodes import NODE_CLASS_MAPPINGS
from totoro_extras import nodes_custom_sampler
from totoro_extras import nodes_flux
from totoro import model_management
import gradio as gr
from IPython.display import clear_output

def download_with_hf_token(url, token, directory, output_name):
    if "huggingface.co" in url:
        url = url.replace("?download=true", "")
        if "/blob/" in url:
            url = url.replace("/blob/", "/resolve/")
        user_header = f'\"Authorization: Bearer {token}\"'
        os.system(f'aria2c --console-log-level=error --header={user_header} -c -x 16 -s 16 -k 1M {url} -d {directory} -o {output_name}')

checkpoint_dir = "/content/TotoroUI/models/checkpoints"
lora_dir = "/content/TotoroUI/models/loras"
os.makedirs(checkpoint_dir, exist_ok=True)
os.makedirs(lora_dir, exist_ok=True)

checkpoint_url = f"https://huggingface.co/camenduru/FLUX.1-dev/resolve/main/flux1-dev-fp8-all-in-one.safetensors"
lora_url = f"https://huggingface.co/{model_repo}/resolve/main/{lora_model}.safetensors"

download_with_hf_token(checkpoint_url, hf_token, checkpoint_dir, "flux1-dev-fp8-all-in-one.safetensors")
download_with_hf_token(lora_url, hf_token, lora_dir, f"{lora_model}.safetensors")

CheckpointLoaderSimple = NODE_CLASS_MAPPINGS["CheckpointLoaderSimple"]()
LoraLoader = NODE_CLASS_MAPPINGS["LoraLoader"]()
FluxGuidance = nodes_flux.NODE_CLASS_MAPPINGS["FluxGuidance"]()
RandomNoise = nodes_custom_sampler.NODE_CLASS_MAPPINGS["RandomNoise"]()
BasicGuider = nodes_custom_sampler.NODE_CLASS_MAPPINGS["BasicGuider"]()
KSamplerSelect = nodes_custom_sampler.NODE_CLASS_MAPPINGS["KSamplerSelect"]()
BasicScheduler = nodes_custom_sampler.NODE_CLASS_MAPPINGS["BasicScheduler"]()
SamplerCustomAdvanced = nodes_custom_sampler.NODE_CLASS_MAPPINGS["SamplerCustomAdvanced"]()
VAELoader = NODE_CLASS_MAPPINGS["VAELoader"]()
VAEDecode = NODE_CLASS_MAPPINGS["VAEDecode"]()
EmptyLatentImage = NODE_CLASS_MAPPINGS["EmptyLatentImage"]()

with torch.inference_mode():
    unet, clip, vae = CheckpointLoaderSimple.load_checkpoint("flux1-dev-fp8-all-in-one.safetensors")
def closestNumber(n, m):
    q = int(n / m)
    n1 = m * q
    if (n * m) > 0:
        n2 = m * (q + 1)
    else:
        n2 = m * (q - 1)
    if abs(n - n1) < abs(n - n2):
        return n1
    return n2

@torch.inference_mode()
def generate(positive_prompt, width, height, seed, steps, sampler_name, scheduler, guidance, lora_strength_model, lora_strength_clip):
    global unet, clip

    clear_output()

    if seed == 0:
        seed = random.randint(0, 18446744073709551615)

    unet_lora, clip_lora = LoraLoader.load_lora(unet, clip, f"{lora_model}.safetensors", lora_strength_model, lora_strength_clip)

    cond, pooled = clip_lora.encode_from_tokens(clip_lora.tokenize(positive_prompt), return_pooled=True)
    cond = [[cond, {"pooled_output": pooled}]]
    cond = FluxGuidance.append(cond, guidance)[0]

    noise = RandomNoise.get_noise(seed)[0]
    guider = BasicGuider.get_guider(unet_lora, cond)[0]
    sampler = KSamplerSelect.get_sampler(sampler_name)[0]
    sigmas = BasicScheduler.get_sigmas(unet_lora, scheduler, steps, 1.0)[0]
    latent_image = EmptyLatentImage.generate(closestNumber(width, 16), closestNumber(height, 16))[0]
    sample, sample_denoised = SamplerCustomAdvanced.sample(noise, guider, sampler, sigmas, latent_image)
    decoded = VAEDecode.decode(vae, sample)[0].detach()

    output_path = "/content/flux.png"
    Image.fromarray(np.array(decoded*255, dtype=np.uint8)[0]).save(output_path)

    return output_path

with gr.Blocks(analytics_enabled=False) as demo:
    with gr.Row():
        with gr.Column():
            positive_prompt = gr.Textbox(lines=3, interactive=True, value="A small kitten sits next to a palm tree on a sunny beach, the kitten is about 3 months old, it has light grey fur, its eyes are very large and blue, it looks very playful and cute, around it are a few flowers and palm leaves, the sun's rays shine through the palm tree, creating a very idyllic atmosphere, there are no people around, only the natural landscape of the beach, the kitten looks very alone, but very content. Below it in the sand is written 'by: mikus', and slightly below that 'code: camenduru', a little further away from the text lies a single piece of seaweed, which looks very unusual.", label="Prompt")
            width = gr.Slider(minimum=256, maximum=2048, value=1024, step=16, label="width")
            height = gr.Slider(minimum=256, maximum=2048, value=1024, step=16, label="height")
            seed = gr.Slider(minimum=0, maximum=18446744073709551615, value=0, step=1, label="seed (0=random)")
            steps = gr.Slider(minimum=4, maximum=50, value=20, step=1, label="steps")
            guidance = gr.Slider(minimum=0, maximum=20, value=3.5, step=0.5, label="guidance")
            lora_strength_model = gr.Slider(minimum=0, maximum=1, value=1.0, step=0.1, label="lora_strength_model")
            lora_strength_clip = gr.Slider(minimum=0, maximum=1, value=1.0, step=0.1, label="lora_strength_clip")
            sampler_name = gr.Dropdown(["euler", "heun", "heunpp2", "dpm_2", "lms", "ddim"], label="sampler_name", value="euler")
            scheduler = gr.Dropdown(["normal", "sgm_uniform", "simple", "ddim_uniform"], label="scheduler", value="simple")
            generate_button = gr.Button("Generate")
        with gr.Column():
            output_image = gr.Image(label="Generated image", interactive=False)

    generate_button.click(fn=generate, inputs=[positive_prompt, width, height, seed, steps, sampler_name, scheduler, guidance, lora_strength_model, lora_strength_clip], outputs=output_image)

demo.queue().launch(inline=False, share=True, debug=True)
# Out:
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.0.norm.linear.lora_A.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.0.norm.linear.lora_B.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.0.proj_mlp.lora_A.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.0.proj_mlp.lora_B.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.0.proj_out.lora_A.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.0.proj_out.lora_B.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.1.norm.linear.lora_A.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.1.norm.linear.lora_B.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.1.proj_mlp.lora_A.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.1.proj_mlp.lora_B.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.1.proj_out.lora_A.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.1.proj_out.lora_B.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.10.norm.linear.lora_A.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.10.norm.linear.lora_B.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.10.proj_mlp.lora_A.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.10.proj_mlp.lora_B.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.10.proj_out.lora_A.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.10.proj_out.lora_B.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.11.norm.linear.lora_A.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.11.norm.linear.lora_B.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.11.proj_mlp.lora_A.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.11.proj_mlp.lora_B.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.11.proj_out.lora_A.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.11.proj_out.lora_B.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.12.norm.linear.lora_A.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.12.norm.linear.lora_B.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.12.proj_mlp.lora_A.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.12.proj_mlp.lora_B.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.12.proj_out.lora_A.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.12.proj_out.lora_B.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.13.norm.linear.lora_A.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.13.norm.linear.lora_B.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.13.proj_mlp.lora_A.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.13.proj_mlp.lora_B.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.13.proj_out.lora_A.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.13.proj_out.lora_B.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.14.norm.linear.lora_A.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.14.norm.linear.lora_B.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.14.proj_mlp.lora_A.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.14.proj_mlp.lora_B.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.14.proj_out.lora_A.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.14.proj_out.lora_B.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.15.norm.linear.lora_A.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.15.norm.linear.lora_B.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.15.proj_mlp.lora_A.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.15.proj_mlp.lora_B.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.15.proj_out.lora_A.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.15.proj_out.lora_B.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.16.norm.linear.lora_A.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.16.norm.linear.lora_B.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.16.proj_mlp.lora_A.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.16.proj_mlp.lora_B.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.16.proj_out.lora_A.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.16.proj_out.lora_B.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.17.norm.linear.lora_A.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.17.norm.linear.lora_B.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.17.proj_mlp.lora_A.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.17.proj_mlp.lora_B.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.17.proj_out.lora_A.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.17.proj_out.lora_B.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.18.norm.linear.lora_A.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.18.norm.linear.lora_B.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.18.proj_mlp.lora_A.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.18.proj_mlp.lora_B.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.18.proj_out.lora_A.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.18.proj_out.lora_B.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.19.norm.linear.lora_A.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.19.norm.linear.lora_B.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.19.proj_mlp.lora_A.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.19.proj_mlp.lora_B.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.19.proj_out.lora_A.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.19.proj_out.lora_B.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.2.norm.linear.lora_A.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.2.norm.linear.lora_B.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.2.proj_mlp.lora_A.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.2.proj_mlp.lora_B.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.2.proj_out.lora_A.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.2.proj_out.lora_B.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.20.norm.linear.lora_A.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.20.norm.linear.lora_B.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.20.proj_mlp.lora_A.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.20.proj_mlp.lora_B.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.20.proj_out.lora_A.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.20.proj_out.lora_B.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.21.norm.linear.lora_A.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.21.norm.linear.lora_B.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.21.proj_mlp.lora_A.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.21.proj_mlp.lora_B.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.21.proj_out.lora_A.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.21.proj_out.lora_B.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.22.norm.linear.lora_A.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.22.norm.linear.lora_B.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.22.proj_mlp.lora_A.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.22.proj_mlp.lora_B.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.22.proj_out.lora_A.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.22.proj_out.lora_B.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.23.norm.linear.lora_A.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.23.norm.linear.lora_B.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.23.proj_mlp.lora_A.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.23.proj_mlp.lora_B.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.23.proj_out.lora_A.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.23.proj_out.lora_B.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.24.norm.linear.lora_A.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.24.norm.linear.lora_B.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.24.proj_mlp.lora_A.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.24.proj_mlp.lora_B.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.24.proj_out.lora_A.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.24.proj_out.lora_B.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.25.norm.linear.lora_A.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.25.norm.linear.lora_B.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.25.proj_mlp.lora_A.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.25.proj_mlp.lora_B.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.25.proj_out.lora_A.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.25.proj_out.lora_B.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.26.norm.linear.lora_A.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.26.norm.linear.lora_B.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.26.proj_mlp.lora_A.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.26.proj_mlp.lora_B.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.26.proj_out.lora_A.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.26.proj_out.lora_B.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.27.norm.linear.lora_A.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.27.norm.linear.lora_B.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.27.proj_mlp.lora_A.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.27.proj_mlp.lora_B.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.27.proj_out.lora_A.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.27.proj_out.lora_B.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.28.norm.linear.lora_A.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.28.norm.linear.lora_B.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.28.proj_mlp.lora_A.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.28.proj_mlp.lora_B.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.28.proj_out.lora_A.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.28.proj_out.lora_B.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.29.norm.linear.lora_A.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.29.norm.linear.lora_B.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.29.proj_mlp.lora_A.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.29.proj_mlp.lora_B.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.29.proj_out.lora_A.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.29.proj_out.lora_B.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.3.norm.linear.lora_A.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.3.norm.linear.lora_B.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.3.proj_mlp.lora_A.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.3.proj_mlp.lora_B.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.3.proj_out.lora_A.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.3.proj_out.lora_B.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.30.norm.linear.lora_A.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.30.norm.linear.lora_B.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.30.proj_mlp.lora_A.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.30.proj_mlp.lora_B.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.30.proj_out.lora_A.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.30.proj_out.lora_B.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.31.norm.linear.lora_A.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.31.norm.linear.lora_B.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.31.proj_mlp.lora_A.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.31.proj_mlp.lora_B.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.31.proj_out.lora_A.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.31.proj_out.lora_B.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.32.norm.linear.lora_A.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.32.norm.linear.lora_B.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.32.proj_mlp.lora_A.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.32.proj_mlp.lora_B.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.32.proj_out.lora_A.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.32.proj_out.lora_B.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.33.norm.linear.lora_A.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.33.norm.linear.lora_B.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.33.proj_mlp.lora_A.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.33.proj_mlp.lora_B.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.33.proj_out.lora_A.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.33.proj_out.lora_B.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.34.norm.linear.lora_A.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.34.norm.linear.lora_B.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.34.proj_mlp.lora_A.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.34.proj_mlp.lora_B.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.34.proj_out.lora_A.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.34.proj_out.lora_B.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.35.norm.linear.lora_A.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.35.norm.linear.lora_B.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.35.proj_mlp.lora_A.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.35.proj_mlp.lora_B.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.35.proj_out.lora_A.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.35.proj_out.lora_B.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.36.norm.linear.lora_A.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.36.norm.linear.lora_B.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.36.proj_mlp.lora_A.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.36.proj_mlp.lora_B.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.36.proj_out.lora_A.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.36.proj_out.lora_B.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.37.norm.linear.lora_A.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.37.norm.linear.lora_B.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.37.proj_mlp.lora_A.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.37.proj_mlp.lora_B.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.37.proj_out.lora_A.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.37.proj_out.lora_B.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.4.norm.linear.lora_A.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.4.norm.linear.lora_B.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.4.proj_mlp.lora_A.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.4.proj_mlp.lora_B.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.4.proj_out.lora_A.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.4.proj_out.lora_B.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.5.norm.linear.lora_A.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.5.norm.linear.lora_B.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.5.proj_mlp.lora_A.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.5.proj_mlp.lora_B.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.5.proj_out.lora_A.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.5.proj_out.lora_B.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.6.norm.linear.lora_A.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.6.norm.linear.lora_B.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.6.proj_mlp.lora_A.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.6.proj_mlp.lora_B.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.6.proj_out.lora_A.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.6.proj_out.lora_B.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.7.norm.linear.lora_A.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.7.norm.linear.lora_B.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.7.proj_mlp.lora_A.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.7.proj_mlp.lora_B.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.7.proj_out.lora_A.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.7.proj_out.lora_B.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.8.norm.linear.lora_A.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.8.norm.linear.lora_B.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.8.proj_mlp.lora_A.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.8.proj_mlp.lora_B.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.8.proj_out.lora_A.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.8.proj_out.lora_B.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.9.norm.linear.lora_A.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.9.norm.linear.lora_B.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.9.proj_mlp.lora_A.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.9.proj_mlp.lora_B.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.9.proj_out.lora_A.weight
# WARNING:root:lora key not loaded: transformer.single_transformer_blocks.9.proj_out.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.0.attn.add_k_proj.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.0.attn.add_k_proj.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.0.attn.add_q_proj.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.0.attn.add_q_proj.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.0.attn.add_v_proj.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.0.attn.add_v_proj.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.0.attn.to_add_out.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.0.attn.to_add_out.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.0.ff.net.0.proj.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.0.ff.net.0.proj.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.0.ff.net.2.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.0.ff.net.2.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.0.ff_context.net.0.proj.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.0.ff_context.net.0.proj.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.0.ff_context.net.2.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.0.ff_context.net.2.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.0.norm1.linear.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.0.norm1.linear.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.0.norm1_context.linear.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.0.norm1_context.linear.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.1.attn.add_k_proj.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.1.attn.add_k_proj.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.1.attn.add_q_proj.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.1.attn.add_q_proj.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.1.attn.add_v_proj.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.1.attn.add_v_proj.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.1.attn.to_add_out.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.1.attn.to_add_out.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.1.ff.net.0.proj.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.1.ff.net.0.proj.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.1.ff.net.2.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.1.ff.net.2.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.1.ff_context.net.0.proj.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.1.ff_context.net.0.proj.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.1.ff_context.net.2.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.1.ff_context.net.2.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.1.norm1.linear.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.1.norm1.linear.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.1.norm1_context.linear.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.1.norm1_context.linear.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.10.attn.add_k_proj.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.10.attn.add_k_proj.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.10.attn.add_q_proj.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.10.attn.add_q_proj.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.10.attn.add_v_proj.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.10.attn.add_v_proj.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.10.attn.to_add_out.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.10.attn.to_add_out.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.10.ff.net.0.proj.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.10.ff.net.0.proj.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.10.ff.net.2.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.10.ff.net.2.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.10.ff_context.net.0.proj.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.10.ff_context.net.0.proj.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.10.ff_context.net.2.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.10.ff_context.net.2.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.10.norm1.linear.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.10.norm1.linear.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.10.norm1_context.linear.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.10.norm1_context.linear.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.11.attn.add_k_proj.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.11.attn.add_k_proj.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.11.attn.add_q_proj.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.11.attn.add_q_proj.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.11.attn.add_v_proj.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.11.attn.add_v_proj.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.11.attn.to_add_out.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.11.attn.to_add_out.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.11.ff.net.0.proj.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.11.ff.net.0.proj.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.11.ff.net.2.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.11.ff.net.2.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.11.ff_context.net.0.proj.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.11.ff_context.net.0.proj.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.11.ff_context.net.2.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.11.ff_context.net.2.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.11.norm1.linear.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.11.norm1.linear.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.11.norm1_context.linear.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.11.norm1_context.linear.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.12.attn.add_k_proj.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.12.attn.add_k_proj.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.12.attn.add_q_proj.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.12.attn.add_q_proj.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.12.attn.add_v_proj.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.12.attn.add_v_proj.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.12.attn.to_add_out.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.12.attn.to_add_out.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.12.ff.net.0.proj.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.12.ff.net.0.proj.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.12.ff.net.2.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.12.ff.net.2.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.12.ff_context.net.0.proj.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.12.ff_context.net.0.proj.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.12.ff_context.net.2.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.12.ff_context.net.2.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.12.norm1.linear.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.12.norm1.linear.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.12.norm1_context.linear.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.12.norm1_context.linear.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.13.attn.add_k_proj.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.13.attn.add_k_proj.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.13.attn.add_q_proj.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.13.attn.add_q_proj.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.13.attn.add_v_proj.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.13.attn.add_v_proj.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.13.attn.to_add_out.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.13.attn.to_add_out.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.13.ff.net.0.proj.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.13.ff.net.0.proj.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.13.ff.net.2.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.13.ff.net.2.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.13.ff_context.net.0.proj.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.13.ff_context.net.0.proj.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.13.ff_context.net.2.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.13.ff_context.net.2.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.13.norm1.linear.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.13.norm1.linear.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.13.norm1_context.linear.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.13.norm1_context.linear.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.14.attn.add_k_proj.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.14.attn.add_k_proj.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.14.attn.add_q_proj.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.14.attn.add_q_proj.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.14.attn.add_v_proj.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.14.attn.add_v_proj.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.14.attn.to_add_out.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.14.attn.to_add_out.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.14.ff.net.0.proj.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.14.ff.net.0.proj.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.14.ff.net.2.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.14.ff.net.2.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.14.ff_context.net.0.proj.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.14.ff_context.net.0.proj.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.14.ff_context.net.2.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.14.ff_context.net.2.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.14.norm1.linear.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.14.norm1.linear.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.14.norm1_context.linear.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.14.norm1_context.linear.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.15.attn.add_k_proj.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.15.attn.add_k_proj.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.15.attn.add_q_proj.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.15.attn.add_q_proj.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.15.attn.add_v_proj.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.15.attn.add_v_proj.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.15.attn.to_add_out.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.15.attn.to_add_out.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.15.ff.net.0.proj.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.15.ff.net.0.proj.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.15.ff.net.2.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.15.ff.net.2.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.15.ff_context.net.0.proj.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.15.ff_context.net.0.proj.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.15.ff_context.net.2.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.15.ff_context.net.2.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.15.norm1.linear.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.15.norm1.linear.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.15.norm1_context.linear.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.15.norm1_context.linear.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.16.attn.add_k_proj.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.16.attn.add_k_proj.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.16.attn.add_q_proj.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.16.attn.add_q_proj.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.16.attn.add_v_proj.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.16.attn.add_v_proj.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.16.attn.to_add_out.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.16.attn.to_add_out.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.16.ff.net.0.proj.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.16.ff.net.0.proj.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.16.ff.net.2.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.16.ff.net.2.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.16.ff_context.net.0.proj.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.16.ff_context.net.0.proj.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.16.ff_context.net.2.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.16.ff_context.net.2.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.16.norm1.linear.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.16.norm1.linear.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.16.norm1_context.linear.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.16.norm1_context.linear.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.17.attn.add_k_proj.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.17.attn.add_k_proj.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.17.attn.add_q_proj.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.17.attn.add_q_proj.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.17.attn.add_v_proj.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.17.attn.add_v_proj.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.17.attn.to_add_out.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.17.attn.to_add_out.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.17.ff.net.0.proj.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.17.ff.net.0.proj.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.17.ff.net.2.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.17.ff.net.2.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.17.ff_context.net.0.proj.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.17.ff_context.net.0.proj.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.17.ff_context.net.2.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.17.ff_context.net.2.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.17.norm1.linear.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.17.norm1.linear.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.17.norm1_context.linear.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.17.norm1_context.linear.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.18.attn.add_k_proj.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.18.attn.add_k_proj.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.18.attn.add_q_proj.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.18.attn.add_q_proj.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.18.attn.add_v_proj.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.18.attn.add_v_proj.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.18.attn.to_add_out.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.18.attn.to_add_out.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.18.ff.net.0.proj.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.18.ff.net.0.proj.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.18.ff.net.2.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.18.ff.net.2.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.18.ff_context.net.0.proj.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.18.ff_context.net.0.proj.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.18.ff_context.net.2.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.18.ff_context.net.2.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.18.norm1.linear.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.18.norm1.linear.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.18.norm1_context.linear.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.18.norm1_context.linear.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.2.attn.add_k_proj.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.2.attn.add_k_proj.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.2.attn.add_q_proj.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.2.attn.add_q_proj.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.2.attn.add_v_proj.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.2.attn.add_v_proj.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.2.attn.to_add_out.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.2.attn.to_add_out.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.2.ff.net.0.proj.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.2.ff.net.0.proj.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.2.ff.net.2.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.2.ff.net.2.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.2.ff_context.net.0.proj.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.2.ff_context.net.0.proj.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.2.ff_context.net.2.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.2.ff_context.net.2.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.2.norm1.linear.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.2.norm1.linear.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.2.norm1_context.linear.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.2.norm1_context.linear.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.3.attn.add_k_proj.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.3.attn.add_k_proj.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.3.attn.add_q_proj.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.3.attn.add_q_proj.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.3.attn.add_v_proj.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.3.attn.add_v_proj.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.3.attn.to_add_out.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.3.attn.to_add_out.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.3.ff.net.0.proj.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.3.ff.net.0.proj.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.3.ff.net.2.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.3.ff.net.2.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.3.ff_context.net.0.proj.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.3.ff_context.net.0.proj.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.3.ff_context.net.2.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.3.ff_context.net.2.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.3.norm1.linear.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.3.norm1.linear.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.3.norm1_context.linear.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.3.norm1_context.linear.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.4.attn.add_k_proj.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.4.attn.add_k_proj.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.4.attn.add_q_proj.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.4.attn.add_q_proj.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.4.attn.add_v_proj.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.4.attn.add_v_proj.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.4.attn.to_add_out.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.4.attn.to_add_out.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.4.ff.net.0.proj.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.4.ff.net.0.proj.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.4.ff.net.2.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.4.ff.net.2.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.4.ff_context.net.0.proj.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.4.ff_context.net.0.proj.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.4.ff_context.net.2.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.4.ff_context.net.2.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.4.norm1.linear.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.4.norm1.linear.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.4.norm1_context.linear.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.4.norm1_context.linear.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.5.attn.add_k_proj.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.5.attn.add_k_proj.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.5.attn.add_q_proj.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.5.attn.add_q_proj.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.5.attn.add_v_proj.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.5.attn.add_v_proj.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.5.attn.to_add_out.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.5.attn.to_add_out.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.5.ff.net.0.proj.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.5.ff.net.0.proj.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.5.ff.net.2.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.5.ff.net.2.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.5.ff_context.net.0.proj.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.5.ff_context.net.0.proj.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.5.ff_context.net.2.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.5.ff_context.net.2.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.5.norm1.linear.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.5.norm1.linear.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.5.norm1_context.linear.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.5.norm1_context.linear.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.6.attn.add_k_proj.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.6.attn.add_k_proj.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.6.attn.add_q_proj.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.6.attn.add_q_proj.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.6.attn.add_v_proj.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.6.attn.add_v_proj.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.6.attn.to_add_out.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.6.attn.to_add_out.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.6.ff.net.0.proj.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.6.ff.net.0.proj.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.6.ff.net.2.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.6.ff.net.2.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.6.ff_context.net.0.proj.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.6.ff_context.net.0.proj.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.6.ff_context.net.2.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.6.ff_context.net.2.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.6.norm1.linear.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.6.norm1.linear.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.6.norm1_context.linear.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.6.norm1_context.linear.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.7.attn.add_k_proj.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.7.attn.add_k_proj.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.7.attn.add_q_proj.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.7.attn.add_q_proj.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.7.attn.add_v_proj.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.7.attn.add_v_proj.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.7.attn.to_add_out.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.7.attn.to_add_out.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.7.ff.net.0.proj.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.7.ff.net.0.proj.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.7.ff.net.2.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.7.ff.net.2.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.7.ff_context.net.0.proj.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.7.ff_context.net.0.proj.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.7.ff_context.net.2.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.7.ff_context.net.2.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.7.norm1.linear.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.7.norm1.linear.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.7.norm1_context.linear.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.7.norm1_context.linear.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.8.attn.add_k_proj.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.8.attn.add_k_proj.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.8.attn.add_q_proj.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.8.attn.add_q_proj.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.8.attn.add_v_proj.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.8.attn.add_v_proj.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.8.attn.to_add_out.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.8.attn.to_add_out.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.8.ff.net.0.proj.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.8.ff.net.0.proj.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.8.ff.net.2.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.8.ff.net.2.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.8.ff_context.net.0.proj.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.8.ff_context.net.0.proj.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.8.ff_context.net.2.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.8.ff_context.net.2.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.8.norm1.linear.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.8.norm1.linear.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.8.norm1_context.linear.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.8.norm1_context.linear.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.9.attn.add_k_proj.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.9.attn.add_k_proj.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.9.attn.add_q_proj.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.9.attn.add_q_proj.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.9.attn.add_v_proj.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.9.attn.add_v_proj.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.9.attn.to_add_out.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.9.attn.to_add_out.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.9.ff.net.0.proj.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.9.ff.net.0.proj.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.9.ff.net.2.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.9.ff.net.2.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.9.ff_context.net.0.proj.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.9.ff_context.net.0.proj.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.9.ff_context.net.2.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.9.ff_context.net.2.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.9.norm1.linear.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.9.norm1.linear.lora_B.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.9.norm1_context.linear.lora_A.weight
# WARNING:root:lora key not loaded: transformer.transformer_blocks.9.norm1_context.linear.lora_B.weight
#   0%|          | 0/20 [00:00<?, ?it/s]

# %% [markdown]
# ---

# %% [markdown]
# # Tutorial
